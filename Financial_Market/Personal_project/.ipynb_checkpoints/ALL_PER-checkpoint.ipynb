# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import Ko

# %%
raw_per = pd.read_csv('Data/ALL/ALL_PER_MONTHLY.csv', encoding = 'cp949', header = 7, dtype = 'str')
raw_rt = pd.read_csv('Data/ALL/ALL_SILH_SUIK_RT_MONTHLY_WITH_DIVIDEND.csv', encoding = 'cp949', header = 7, dtype = 'str')

# %%
raw_per.head(7)
# Out:
#           Term      19900101 Current(20180914)    Unnamed: 3    Unnamed: 4  \
# 0       Symbol       A000010           A000011       A000012       A000020
# 1  Symbol Name          조흥은행          조흥은행(1신)      조흥은행(2신)          동화약품
# 2         Kind  NVAL-IFRS(C)      NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)
# 3         Item    6000701002        6000701002    6000701002    6000701002
# 4    Item Name      수정PER(배)          수정PER(배)      수정PER(배)      수정PER(배)
# 5    Frequency        ANNUAL            ANNUAL        ANNUAL        ANNUAL
# 6   1990-01-31         20.34               NaN           NaN         19.17
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 0       A000021       A000022       A000023       A000030       A000031
# 1    동화약품공업(1신)    동화약품(전환1신)    동화약품(전환2신)          우리은행      한빛은행(1신)
# 2  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)
# 3    6000701002    6000701002    6000701002    6000701002    6000701002
# 4      수정PER(배)      수정PER(배)      수정PER(배)      수정PER(배)      수정PER(배)
# 5        ANNUAL        ANNUAL        ANNUAL        ANNUAL        ANNUAL
# 6           NaN           NaN           NaN        445.70           NaN
#
#        ...      Unnamed: 5002 Unnamed: 5003 Unnamed: 5004 Unnamed: 5005  \
# 0      ...            A900310       A950010       A950030       A950070
# 1      ...               컬러레이      평산차업 KDR        네프로아이티          중국고섬
# 2      ...       NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)
# 3      ...         6000701002    6000701002    6000701002    6000701002
# 4      ...           수정PER(배)      수정PER(배)      수정PER(배)      수정PER(배)
# 5      ...             ANNUAL        ANNUAL        ANNUAL        ANNUAL
# 6      ...                NaN           NaN           NaN           NaN
#
#   Unnamed: 5006 Unnamed: 5007 Unnamed: 5008 Unnamed: 5009  Unnamed: 5010  \
# 0       A950100       A950110       A950130       A950140        A950160
# 1        SBI모기지    SBI핀테크솔루션즈        엑세스바이오         잉글우드랩  코오롱티슈진(Reg.S)
# 2  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)  NVAL-IFRS(C)   NVAL-IFRS(C)
# 3    6000701002    6000701002    6000701002    6000701002     6000701002
# 4      수정PER(배)      수정PER(배)      수정PER(배)      수정PER(배)       수정PER(배)
# 5        ANNUAL        ANNUAL        ANNUAL        ANNUAL         ANNUAL
# 6           NaN           NaN           NaN           NaN            NaN
#
#   Unnamed: 5011
# 0       A950170
# 1           JTC
# 2  NVAL-IFRS(C)
# 3    6000701002
# 4      수정PER(배)
# 5        ANNUAL
# 6           NaN
#
# [7 rows x 5012 columns]

# %% [markdown]
# # 성과지표 데이터프레임 전처리 수행

# %%
per_df = Ko.Preprocessing(raw_per, column = '심볼')

# %% [markdown]
# # 수익률 DF 전처리

# %%
rt_df = Ko.Preprocessing(raw_rt, column = '심볼').apply(lambda x: Ko.rt_transform(x))

rt_df = rt_df.loc[per_df.index]
rt_df = rt_df.iloc[:, :-1]

# %%
rt_df.head()
# Out:
#          19900131  19900228  19900331  19900430  19900531  19900630  19900731  \
# A000010    0.9060    0.9407    0.9528    0.8512    1.1845    0.8607    1.0190
# A000020    1.0698    0.9652    0.9552    0.8981    0.9730    0.8611    0.9161
# A000030    0.9000    0.9407    0.9528    0.8595    1.1827    0.8537    1.0190
# A000040    1.1000    0.9870    0.9474    0.8056    1.1552    0.7985    0.9533
# A000050    1.0000    1.0000    1.0000    0.9919    1.0143    1.0020    0.9919
#
#          19900831  19900930  19901031    ...     20171130  20171231  20180131  \
# A000010    0.8458    0.9669    1.3143    ...          NaN       NaN       NaN
# A000020    1.0282    1.0137    1.0541    ...       1.1652    0.9617    1.1077
# A000030    0.8411    0.9778    1.3182    ...       0.9878    1.0029    1.0698
# A000040    0.8431    0.8488    1.3014    ...       0.8589    0.9366    1.2924
# A000050    1.0020    1.0020    0.9980    ...       0.9381    1.0315    1.0432
#
#          20180228  20180331  20180430  20180531  20180630  20180731  20180831
# A000010       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# A000020    1.0556    1.0746    0.9429    0.9913    0.8908    1.0833    1.0498
# A000030    0.9852    0.8825    1.0956    0.9533    1.0654    1.0368    0.9645
# A000040    0.8877    1.0285    1.1560    1.0825    0.8352    0.9701    1.0034
# A000050    0.9690    1.0000    1.0605    0.8758    1.0613    0.9206    1.0784
#
# [5 rows x 344 columns]

# %% [markdown]
# # 포트폴리오 구성 수행

# %%
data = Ko.portfolio_selection(per_df)

# %%
data.head(5)
# Out:
#         19900131 19900228 19900331 19900430 19900531 19900630 19900731  \
# A000010        x        4        4        4        4        4        4
# A000020        x        4        4        4        2        2        2
# A000030        x        9        9        9        9        9        9
# A000040        x        9        9        9        9        9        9
# A000050        x        5        5        5        6        5        6
#
#         19900831 19900930 19901031   ...    20171130 20171231 20180131  \
# A000010        4        4        4   ...           x        x        x
# A000020        2        2        2   ...           0        0        0
# A000030        9        9        9   ...           1        1        1
# A000040        9        9        9   ...           x        x        x
# A000050        6        6        7   ...           4        4        4
#
#         20180228 20180331 20180430 20180531 20180630 20180731 20180831
# A000010        x        x        x        x        x        x        x
# A000020        0        1        1        1        1        1        1
# A000030        1        1        1        1        1        1        1
# A000040        x        x        x        x        x        x        x
# A000050        4        4        4        4        3        4        4
#
# [5 rows x 344 columns]

# %%
#data.to_csv('PER.csv')

# %% [markdown]
# # 포트폴리오 성과분석

# %%
result = Ko.performance_analysis(data, rt_df)
result.index = pd.to_datetime(data.columns, format = '%Y%m%d')

# %%
result.min()
# Out:
# GROUP_0    0.714632
# GROUP_1    0.717996
# GROUP_2    0.730357
# GROUP_3    0.721265
# GROUP_4    0.728238
# GROUP_5    0.708772
# GROUP_6    0.717813
# GROUP_7    0.692089
# GROUP_8    0.688110
# GROUP_9    0.678990
# dtype: float64

# %%
result.max()
# Out:
# GROUP_0    1.787058
# GROUP_1    1.769140
# GROUP_2    1.467289
# GROUP_3    1.362236
# GROUP_4    1.499730
# GROUP_5    1.425826
# GROUP_6    1.493328
# GROUP_7    1.474056
# GROUP_8    1.599158
# GROUP_9    1.714969
# dtype: float64

# %% [markdown]
# # 1990년대

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[:119].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2000 년대

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[120:239].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2010년대

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[240:].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    plt.plot(result[column].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    plt.plot(result[column].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    sns.distplot(result[column], label = column)

plt.legend(loc = 'best')
plt.title('Monthly return distribution by PER Group', fontsize = 20)
# Out:
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\finance lab 16\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Monthly return distribution by PER Group')

# %%
result.describe().apply(lambda x: round(x,3))
# Out:
#        GROUP_0  GROUP_1  GROUP_2  GROUP_3  GROUP_4  GROUP_5  GROUP_6  GROUP_7  \
# count  344.000  344.000  344.000  344.000  344.000  344.000  344.000  344.000
# mean     1.051    1.040    1.031    1.023    1.019    1.014    1.012    1.008
# std      0.105    0.096    0.089    0.083    0.082    0.082    0.086    0.090
# min      0.715    0.718    0.730    0.721    0.728    0.709    0.718    0.692
# 25%      0.997    0.990    0.978    0.972    0.967    0.964    0.964    0.957
# 50%      1.037    1.033    1.024    1.018    1.017    1.011    1.011    1.007
# 75%      1.101    1.075    1.068    1.063    1.061    1.057    1.058    1.050
# max      1.787    1.769    1.467    1.362    1.500    1.426    1.493    1.474
#
#        GROUP_8  GROUP_9
# count  344.000  344.000
# mean     1.004    1.001
# std      0.096    0.102
# min      0.688    0.679
# 25%      0.953    0.951
# 50%      0.999    0.998
# 75%      1.052    1.051
# max      1.599    1.715
