# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import Ko

# %%
raw_per = pd.read_csv('../Data/ALL/Annual/ALL_SIZE_ANNUAL.csv', encoding = 'cp949', header = 7, dtype = 'str')
raw_rt = pd.read_csv('../Data/ALL/Annual/ALL_SILH_SUIK_RT_ANNUAL_NO_DIVIDEND.csv', encoding = 'cp949', header = 7, dtype = 'str')

# %%
raw_per.head(7)
# Out:
#           Term                    19900101                    20180930  \
# 0       Symbol                     A000010                     A000011
# 1  Symbol Name                        조흥은행                    조흥은행(1신)
# 2         Kind                         SSC                         SSC
# 3         Item                  S410001250                  S410001250
# 4    Item Name  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5    Frequency                       DAILY                       DAILY
# 6   1990-12-31                   1,586,000                           0
#
#                    Unnamed: 3                  Unnamed: 4  \
# 0                     A000012                     A000020
# 1                    조흥은행(2신)                        동화약품
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                      33,049
#
#                    Unnamed: 5                  Unnamed: 6  \
# 0                     A000021                     A000022
# 1                  동화약품공업(1신)                  동화약품(전환1신)
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                           0                         NaN
#
#                    Unnamed: 7                  Unnamed: 8  \
# 0                     A000023                     A000030
# 1                  동화약품(전환2신)                        우리은행
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                   1,560,000
#
#                    Unnamed: 9             ...              \
# 0                     A000031             ...
# 1                    한빛은행(1신)             ...
# 2                         SSC             ...
# 3                  S410001250             ...
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)             ...
# 5                       DAILY             ...
# 6                           0             ...
#
#                 Unnamed: 5010               Unnamed: 5011  \
# 0                     A900310                     A950010
# 1                        컬러레이                    평산차업 KDR
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                         NaN
#
#                 Unnamed: 5012               Unnamed: 5013  \
# 0                     A950030                     A950070
# 1                      네프로아이티                        중국고섬
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                         NaN
#
#                 Unnamed: 5014               Unnamed: 5015  \
# 0                     A950100                     A950110
# 1                      SBI모기지                  SBI핀테크솔루션즈
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                         NaN
#
#                 Unnamed: 5016               Unnamed: 5017  \
# 0                     A950130                     A950140
# 1                      엑세스바이오                       잉글우드랩
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                         NaN
#
#                 Unnamed: 5018               Unnamed: 5019
# 0                     A950160                     A950170
# 1               코오롱티슈진(Reg.S)                         JTC
# 2                         SSC                         SSC
# 3                  S410001250                  S410001250
# 4  시가총액 (티커-상장예정주식수 미포함)(백만원)  시가총액 (티커-상장예정주식수 미포함)(백만원)
# 5                       DAILY                       DAILY
# 6                         NaN                         NaN
#
# [7 rows x 5020 columns]

# %% [markdown]
# # 성과지표 데이터프레임 전처리 수행

# %%
per_df = Ko.Preprocessing(raw_per, column = '심볼', drop_limit = 2)

len(per_df)
# Out:
# 3343

# %%
per_df.head(10)
# Out:
#           19901231   19911231   19921231   19931231   19941231   19951231  \
# A000010  1586000.0  1378000.0  1339000.0  1352000.0  1521000.0  1480920.0
# A000020    33049.0    27126.0    37024.0    52920.0   118613.0    63909.0
# A000030  1560000.0  1378000.0  1313000.0  1118000.0  1027000.0  1317500.0
# A000040    33920.0    18400.0    32960.0    37760.0    34240.0    29199.0
# A000041    13500.0    13500.0    13500.0    13500.0    13500.0    13500.0
# A000050    53568.0    54540.0    56800.0    76230.0    93940.0    67606.0
# A000060    82500.0    69300.0    68640.0   108900.0    98670.0   238524.0
# A000070    85800.0   123000.0   226800.0   213840.0   261360.0   201960.0
# A000071     4609.0    12120.0    22500.0    21240.0    21168.0    41412.0
# A000075        NaN        NaN    16259.0    13846.0    10807.0     7900.0
#
#           19961231  19971231   19981231   19991231     ...      20091231  \
# A000010  1228167.0  643857.0   223303.0  2512589.0     ...           NaN
# A000020    70512.0   21960.0    55619.0    74968.0     ...      211721.0
# A000030   938400.0  487900.0  2286637.0  3358089.0     ...      478241.0
# A000040    42939.0   12620.0     8413.0     5231.0     ...       61932.0
# A000041    33060.0       NaN        NaN        NaN     ...           NaN
# A000050    74228.0   27823.0    30293.0    39859.0     ...      267280.0
# A000060   149292.0   68640.0   106392.0    68640.0     ...      846792.0
# A000070   230397.0   71404.0   129132.0   132243.0     ...      446806.0
# A000071        NaN       NaN        NaN        NaN     ...           NaN
# A000075     5631.0    2086.0     4866.0     4296.0     ...        7316.0
#
#           20101231   20111231   20121231   20131231   20141231   20151231  \
# A000010        NaN        NaN        NaN        NaN        NaN        NaN
# A000020   147757.0   113960.0   168706.0   122619.0   155578.0   227362.0
# A000030   478241.0   478241.0   478241.0   478241.0  6762784.0  5962320.0
# A000040    80555.0    79362.0    58955.0    52272.0   123518.0   222641.0
# A000041        NaN        NaN        NaN        NaN        NaN        NaN
# A000050   250640.0   195104.0   186368.0   271660.0   498958.0   527744.0
# A000060  1078298.0  1141060.0  1368305.0  1535131.0  1319239.0  1711302.0
# A000070   699262.0   444378.0   547055.0   609517.0   768215.0  1361719.0
# A000071        NaN        NaN        NaN        NaN        NaN        NaN
# A000075    10607.0     7896.0     6895.0    10338.0    12451.0    20828.0
#
#           20161231    20171231    20180930
# A000010        NaN         NaN         NaN
# A000020   226804.0    272332.0    317022.0
# A000030  8619000.0  10647000.0  11424400.0
# A000040   152000.0     61186.0     75584.0
# A000041        NaN         NaN         NaN
# A000050   419454.0    381072.0    356399.0
# A000060  1688171.0   2592943.0   2199708.0
# A000070  1023430.0   1044841.0    869274.0
# A000071        NaN         NaN         NaN
# A000075    19399.0     16966.0     16784.0
#
# [10 rows x 29 columns]

# %% [markdown]
# # 수익률 DF 전처리

# %%
rt_df = Ko.Preprocessing(raw_rt, column = '심볼', drop_limit = 2).apply(lambda x: Ko.rt_transform(x))

rt_df = rt_df.loc[per_df.index]
rt_df = rt_df.iloc[:, :-1]

# %%
rt_df.head()
# Out:
#          19901231  19911231  19921231  19931231  19941231  19951231  19961231  \
# A000010    0.8188    0.8689    0.9717    1.0400    1.2105    0.7921    0.7560
# A000020    0.8185    0.8322    1.4148    1.2452    2.2504    0.5620    0.9526
# A000030    0.8000    0.8833    0.9528    0.8731    0.9847    0.9810    0.7216
# A000040    0.7571    0.5425    1.7913    1.1683    0.9068    0.7944    1.4471
# A000041    1.0630    1.0630    1.0630    1.0630    1.0630    1.0630    1.5882
#
#          19971231  19981231  19991231    ...     20081231  20091231  20101231  \
# A000010    0.5406    0.3468    0.6840    ...          NaN       NaN       NaN
# A000020    0.2715    2.5781    1.0949    ...       0.5765    1.2265    0.6979
# A000030    0.5345    0.2705    0.5818    ...       1.0000    1.0000    1.0000
# A000040    0.0967    0.6666    0.6218    ...       0.3075    1.8986    1.2052
# A000041    1.5882       NaN       NaN    ...          NaN       NaN       NaN
#
#          20111231  20121231  20131231  20141231  20151231  20161231  20171231
# A000010       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# A000020    0.7713    1.4804    0.7268    1.2688    1.4614    0.9975    1.2007
# A000030    1.0000    1.0000    1.0000    0.6494    0.8820    1.4456    1.2353
# A000040    0.9852    0.7423    0.8869    2.3627    1.2274    0.6792    0.3767
# A000041       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # 포트폴리오 구성 수행

# %%
data = Ko.portfolio_selection(per_df)

# %%
data.head(10)
# Out:
#         19901231 19911231 19921231 19931231 19941231 19951231 19961231  \
# A000010        x        9        9        9        9        9        9
# A000020        x        6        6        6        6        7        6
# A000030        x        9        9        9        9        9        9
# A000040        x        6        5        6        5        4        4
# A000041        x        3        4        3        2        2        2
# A000050        x        7        7        7        7        7        6
# A000060        x        8        7        7        7        7        9
# A000070        x        8        8        9        8        9        8
# A000071        x        1        4        5        4        3        5
# A000075        x        x        x        4        2        2        2
#
#         19971231 19981231 19991231   ...    20081231 20091231 20101231  \
# A000010        9        9        9   ...           x        x        x
# A000020        7        6        7   ...           8        8        8
# A000030        9        9        9   ...           8        9        8
# A000040        6        4        3   ...           6        5        5
# A000041        5        x        x   ...           x        x        x
# A000050        7        7        6   ...           8        8        8
# A000060        8        8        8   ...           9        9        9
# A000070        9        8        8   ...           8        8        8
# A000071        x        x        x   ...           x        x        x
# A000075        1        1        2   ...           0        1        0
#
#         20111231 20121231 20131231 20141231 20151231 20161231 20171231
# A000010        x        x        x        x        x        x        x
# A000020        7        6        7        6        6        7        7
# A000030        8        8        8        8        9        9        9
# A000040        5        5        4        4        6        7        6
# A000041        x        x        x        x        x        x        x
# A000050        8        7        7        8        8        8        8
# A000060        9        9        9        9        9        9        9
# A000070        9        8        8        8        8        9        9
# A000071        x        x        x        x        x        x        x
# A000075        0        0        0        0        0        0        0
#
# [10 rows x 28 columns]

# %%
#data.to_csv('PER.csv')

# %% [markdown]
# # 포트폴리오 성과분석

# %%
result = Ko.performance_analysis(data, rt_df)
result.index = pd.to_datetime(data.columns, format = '%Y%m%d')

# %%
result.min()
# Out:
# GROUP_0    0.581940
# GROUP_1    0.526785
# GROUP_2    0.508414
# GROUP_3    0.416553
# GROUP_4    0.457604
# GROUP_5    0.473638
# GROUP_6    0.390897
# GROUP_7    0.361788
# GROUP_8    0.390358
# GROUP_9    0.478716
# dtype: float64

# %%
result.max()
# Out:
# GROUP_0    4.668924
# GROUP_1    3.499055
# GROUP_2    3.420010
# GROUP_3    3.531952
# GROUP_4    3.443910
# GROUP_5    2.473374
# GROUP_6    2.105362
# GROUP_7    2.005007
# GROUP_8    1.885055
# GROUP_9    1.750636
# dtype: float64

# %% [markdown]
# # 1990년대

# %%
result.head(10)
# Out:
#              GROUP_0   GROUP_1   GROUP_2   GROUP_3   GROUP_4   GROUP_5  \
# 1990-12-31  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1991-12-31  0.962378  0.825234  0.850606  0.816134  0.855064  0.804643
# 1992-12-31  1.281971  1.395102  1.331401  1.473651  1.307149  1.305460
# 1993-12-31  1.296698  1.294198  1.423007  1.298135  1.330878  1.334659
# 1994-12-31  1.033178  1.244297  1.345245  1.383077  1.470691  1.317703
# 1995-12-31  0.882071  0.917322  0.814919  0.730509  0.779326  0.739667
# 1996-12-31  0.930871  1.025122  1.109826  1.184244  1.076504  0.932971
# 1997-12-31  0.601668  0.758280  0.563017  0.416553  0.544080  0.474000
# 1998-12-31  1.428809  1.728217  1.541788  1.370155  1.329760  1.358050
# 1999-12-31  4.668924  3.039897  3.420010  3.531952  3.443910  2.473374
#
#              GROUP_6   GROUP_7   GROUP_8   GROUP_9
# 1990-12-31  1.000000  1.000000  1.000000  1.000000
# 1991-12-31  0.854507  0.926031  0.901495  0.897361
# 1992-12-31  1.254931  1.327534  1.144159  1.024145
# 1993-12-31  1.384902  1.406799  1.331992  1.272567
# 1994-12-31  1.333543  1.222476  1.114068  1.091451
# 1995-12-31  0.714344  0.724904  0.769686  0.845467
# 1996-12-31  0.908758  0.863186  0.785750  0.686753
# 1997-12-31  0.390897  0.361788  0.428690  0.532097
# 1998-12-31  1.490252  1.591352  1.361159  1.470110
# 1999-12-31  1.372042  1.262669  1.339086  1.432173

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[:10].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2000 년대

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[11:20].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2010년대

# %%
plt.figure(figsize = (20,10))

for column in result.columns:
    plt.plot(result[column].iloc[21:].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    plt.plot(result[column].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    sns.distplot(result[column], label = column)

plt.legend(loc = 'best')
plt.title('Monthly return distribution by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Monthly return distribution by PER Group')

# %%
result.describe().apply(lambda x: round(x,3))
# Out:
#        GROUP_0  GROUP_1  GROUP_2  GROUP_3  GROUP_4  GROUP_5  GROUP_6  GROUP_7  \
# count   28.000   28.000   28.000   28.000   28.000   28.000   28.000   28.000
# mean     1.302    1.279    1.269    1.216    1.173    1.109    1.076    1.073
# std      0.794    0.633    0.607    0.598    0.593    0.440    0.355    0.356
# min      0.582    0.527    0.508    0.417    0.458    0.474    0.391    0.362
# 25%      0.928    0.974    1.011    0.946    0.861    0.911    0.895    0.897
# 50%      1.089    1.135    1.132    1.099    1.046    1.027    1.055    1.072
# 75%      1.310    1.368    1.365    1.373    1.313    1.277    1.265    1.265
# max      4.669    3.499    3.420    3.532    3.444    2.473    2.105    2.005
#
#        GROUP_8  GROUP_9
# count   28.000   28.000
# mean     1.057    1.081
# std      0.317    0.323
# min      0.390    0.479
# 25%      0.898    0.891
# 50%      1.068    1.037
# 75%      1.233    1.311
# max      1.885    1.751
