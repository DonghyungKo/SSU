# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import Ko

# %%
raw_per = pd.read_csv('../Data/ALL/Annual/ALL_SIZE_ANNUAL.csv', encoding = 'cp949', header = 7, dtype = 'str')
raw_rt = pd.read_csv('../Data/ALL/Annual/ALL_SILH_SUIK_RT_ANNUAL_NO_DIVIDEND.csv', encoding = 'cp949', header = 7, dtype = 'str')

# %% [markdown]
# ## **전체기간 총 상장 주식 수는 5014개**

# %%
stock_name_ls = raw_rt.iloc[1,1:].tolist()

# %%
len(stock_name_ls)
# Out:
# 5019

# %% [markdown]
# ## **보통주만 선별하는 작업 필요**

# %%
stock_name_ls[:10]
# Out:
# ['조흥은행',
#  '조흥은행(1신)',
#  '조흥은행(2신)',
#  '동화약품',
#  '동화약품공업(1신)',
#  '동화약품(전환1신)',
#  '동화약품(전환2신)',
#  '우리은행',
#  '한빛은행(1신)',
#  '한국상업은행(2신)']

# %% [markdown]
# ## **Raw 데이터에 문제가 있는 16개 기업 제거**

# %%
error_stock_ls = ['삼성물산','알루코','하나은행','두산건설','SK',
                  '고려시멘트','광주은행','경남은행','신성이엔지', '에스와이코퍼레이션',
                  '현대리바트','세원','풀무원','국민은행','핸디소프트','아이티센']

# %%
stock_name_ls = [x for x in stock_name_ls if not x in error_stock_ls]

# %%
def clean_uncommon_stocks(stock_name_ls):
    # (1신) 꼴 제거
    unwanted_word_ls = ['(', '1신', '2신', '3신','4신','우B','우C','1','2','3','우선','스팩']
    
    for unwanted_word in unwanted_word_ls:
        stock_name_ls = [x for x in stock_name_ls if not unwanted_word in x]
    
    stock_name_ls = [x for x in stock_name_ls if not x[-1] == '우']
    return stock_name_ls

# %% [markdown]
# ## **최종적으로 선정된 주식의 수는 2900개**

# %%
common_stock_ls = clean_uncommon_stocks(stock_name_ls)
len(common_stock_ls)
# Out:
# 2904

# %% [markdown]
# # 성과지표 데이터프레임 전처리 수행

# %%
per_df = Ko.Preprocessing(raw_per, column = '기업명', drop_limit=0)
per_df = per_df.loc[common_stock_ls]

# %%
len(per_df)
# Out:
# 2904

# %% [markdown]
# # 수익률 DF 전처리

# %%
rt_df = Ko.Preprocessing(raw_rt, column = '기업명', drop_limit=0).apply(lambda x: Ko.rt_transform(x), axis = 1)

rt_df = rt_df.loc[per_df.index]
rt_df = rt_df.iloc[:, :-1]

# %%
rt_df.loc['조흥은행'].iloc[173:178]
# Out:
# Series([], Name: 조흥은행, dtype: float64)

# %%
len(rt_df)
# Out:
# 2904

# %%
rt_df.max(axis = 1).sort_values(ascending = False)
# Out:
# 한글과컴퓨터       125.2411
# 솔본           112.5581
# 테라            82.1900
# 한국정보통신        49.9694
# 큐캐피탈          47.4391
# 유비케어          41.7411
# 진원생명과학        38.6802
# 디패션           38.4327
# 엔에스엔          38.3647
# 터보테크          36.2738
# 에듀패스          36.1407
# 스타맥스          35.5129
# 카카오           34.5069
# 대신정보통신        33.0189
# 팬텀엔터그룹        32.7789
# 디지틀조선         32.7089
# 위너지스          31.6081
# 정산애강          31.4888
# 모아텍           30.1589
# 한솔로지스틱스       27.1987
# 세원물산          27.1607
# 대동신금          23.6895
# SBI인베스트먼트     23.3776
# 한일사료          23.3393
# 후야인포넷         22.2932
# 휴맥스홀딩스        21.1832
# 에프앤리퍼블릭       20.6000
# 삼보컴퓨터         19.6118
# 삼보산업          18.3163
# 제이엠아이         16.5050
#                ...
# 올릭스               NaN
# EDGC              NaN
# SG                NaN
# 명성티엔에스            NaN
# 세종메디칼             NaN
# 알리코제약             NaN
# 케어랩스              NaN
# 씨앤지하이테크           NaN
# 배럴                NaN
# 에스에스알             NaN
# 린드먼아시아            NaN
# 쿠쿠홈시스             NaN
# SK케미칼             NaN
# 롯데정보통신            NaN
# 에스퓨얼셀             NaN
# SV인베스트먼트          NaN
# 휴네시온              NaN
# 대유                NaN
# 푸드나무              NaN
# 액트로               NaN
# 하나제약              NaN
# 나우아이비캐피탈          NaN
# HDC현대산업개발         NaN
# 효성화학              NaN
# 효성티앤씨             NaN
# 효성중공업             NaN
# 효성첨단소재            NaN
# 한일시멘트             NaN
# 세아제강              NaN
# JTC               NaN
# Length: 2904, dtype: float64

# %% [markdown]
# # 포트폴리오 구성 수행

# %%
data = Ko.portfolio_selection(per_df)

# %%
data.head(5)
# Out:
#       19901231 19911231 19921231 19931231 19941231 19951231 19961231 19971231  \
# 조흥은행         x        9        9        9        9        9        9        9
# 동화약품         x        5        5        5        5        6        5        7
# 우리은행         x        9        9        9        9        9        9        9
# KR모터스        x        5        4        5        4        2        3        5
# 경방           x        6        7        6        6        6        5        7
#
#       19981231 19991231   ...    20081231 20091231 20101231 20111231 20121231  \
# 조흥은행         9        9   ...           x        x        x        x        x
# 동화약품         6        7   ...           8        8        8        7        6
# 우리은행         9        9   ...           8        9        8        8        8
# KR모터스        4        3   ...           6        5        5        5        5
# 경방           6        6   ...           8        8        8        8        7
#
#       20131231 20141231 20151231 20161231 20171231
# 조흥은행         x        x        x        x        x
# 동화약품         7        6        6        7        7
# 우리은행         8        8        9        9        9
# KR모터스        4        3        5        6        5
# 경방           7        7        8        8        8
#
# [5 rows x 28 columns]

# %% [markdown]
# # 포트폴리오 성과분석

# %%
result = Ko.performance_analysis(data, rt_df)
result.index = pd.to_datetime(data.columns, format = '%Y%m%d')

# %%
result.min()
# Out:
# GROUP_0    0.568899
# GROUP_1    0.533158
# GROUP_2    0.478832
# GROUP_3    0.491124
# GROUP_4    0.457600
# GROUP_5    0.477031
# GROUP_6    0.410078
# GROUP_7    0.405909
# GROUP_8    0.401372
# GROUP_9    0.413102
# dtype: float64

# %%
result.max()
# Out:
# GROUP_0    5.317715
# GROUP_1    3.431297
# GROUP_2    4.094590
# GROUP_3    3.676991
# GROUP_4    3.450747
# GROUP_5    2.187499
# GROUP_6    2.026635
# GROUP_7    2.109355
# GROUP_8    1.857835
# GROUP_9    1.746077
# dtype: float64

# %% [markdown]
# # 1990년대

# %%
plt.figure(figsize = (10,5))

for column in result.columns:
    plt.plot(result[column].iloc[0:10].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2000년대

# %%
plt.figure(figsize = (10,5))

for column in result.columns:
    plt.plot(result[column].iloc[10:20].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %% [markdown]
# # 2010년대

# %%
plt.figure(figsize = (10,5))

for column in result.columns:
    plt.plot(result[column].iloc[20:].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
plt.figure(figsize = (12,6))

for column in result.columns:
    plt.plot(result[column].cumprod(), label = column)

plt.legend(loc = 'best')
plt.title('Performance result by PER Group', fontsize = 20)
# Out:
# Text(0.5,1,'Performance result by PER Group')

# %%
summary_df = result.describe().apply(lambda x: round(x,3))
summary_df.loc['count'] = result.prod().apply(lambda x: np.power(x,1/len(result)))
summary_df.rename({'count' : 'geo_mean_return',
                    'mean' : 'arith_mean_return'},
                  inplace = True)
summary_df.apply(lambda x: round(x,3))
# Out:
#                    GROUP_0  GROUP_1  GROUP_2  GROUP_3  GROUP_4  GROUP_5  \
# geo_mean_return      1.217    1.207    1.150    1.105    1.066    1.037
# arith_mean_return    1.394    1.308    1.264    1.210    1.168    1.105
# std                  0.946    0.614    0.689    0.623    0.592    0.407
# min                  0.569    0.533    0.479    0.491    0.458    0.477
# 25%                  0.915    1.006    0.952    0.885    0.876    0.925
# 50%                  1.163    1.162    1.107    1.094    1.031    1.040
# 75%                  1.419    1.409    1.354    1.355    1.303    1.218
# max                  5.318    3.431    4.095    3.677    3.451    2.187
#
#                    GROUP_6  GROUP_7  GROUP_8  GROUP_9
# geo_mean_return      1.019    1.013    1.001    1.036
# arith_mean_return    1.080    1.075    1.052    1.090
# std                  0.358    0.362    0.311    0.336
# min                  0.410    0.406    0.401    0.413
# 25%                  0.916    0.863    0.896    0.882
# 50%                  1.035    1.053    1.075    1.034
# 75%                  1.272    1.241    1.230    1.303
# max                  2.027    2.109    1.858    1.746

# %%
summary_df = result.describe().apply(lambda x: round(x,3))
summary_df.loc['count'] = result.prod().apply(lambda x: np.power(x,1/len(result)))
summary_df.rename({'count' : 'geo_mean_return',
                    'mean' : 'arith_mean_return'},
                  inplace = True)
summary_df.apply(lambda x: round(x,3))
# Out:
#                    GROUP_0  GROUP_1  GROUP_2  GROUP_3  GROUP_4  GROUP_5  \
# geo_mean_return      1.217    1.207    1.150    1.105    1.066    1.037
# arith_mean_return    1.394    1.308    1.264    1.210    1.168    1.105
# std                  0.946    0.614    0.689    0.623    0.592    0.407
# min                  0.569    0.533    0.479    0.491    0.458    0.477
# 25%                  0.915    1.006    0.952    0.885    0.876    0.925
# 50%                  1.163    1.162    1.107    1.094    1.031    1.040
# 75%                  1.419    1.409    1.354    1.355    1.303    1.218
# max                  5.318    3.431    4.095    3.677    3.451    2.187
#
#                    GROUP_6  GROUP_7  GROUP_8  GROUP_9
# geo_mean_return      1.019    1.013    1.001    1.036
# arith_mean_return    1.080    1.075    1.052    1.090
# std                  0.358    0.362    0.311    0.336
# min                  0.410    0.406    0.401    0.413
# 25%                  0.916    0.863    0.896    0.882
# 50%                  1.035    1.053    1.075    1.034
# 75%                  1.272    1.241    1.230    1.303
# max                  2.027    2.109    1.858    1.746
